# %%
import cv2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
gambar1 = cv2.imread('gambar/1.jpg')

# %%
plt.imshow(gambar1)

# %%
cv2.imshow('kadal', gambar1)
cv2.waitKey()
# Out:
# -1
