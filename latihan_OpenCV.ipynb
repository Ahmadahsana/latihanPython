# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('gambar/2.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img
# Out:
# array([[[204, 202, 202],
#         [204, 202, 202],
#         [198, 198, 198],
#         ...,
#         [225, 230, 231],
#         [225, 230, 231],
#         [225, 230, 231]],
#
#        [[207, 205, 205],
#         [207, 205, 205],
#         [202, 202, 202],
#         ...,
#         [223, 228, 229],
#         [224, 229, 230],
#         [225, 230, 231]],
#
#        [[205, 205, 205],
#         [206, 206, 206],
#         [204, 204, 204],
#         ...,
#         [223, 228, 229],
#         [224, 229, 230],
#         [225, 230, 231]],
#
#        ...,
#
#        [[123, 173, 191],
#         [123, 173, 191],
#         [126, 174, 192],
#         ...,
#         [242, 250, 250],
#         [242, 247, 246],
#         [240, 245, 244]],
#
#        [[124, 172, 190],
#         [128, 176, 194],
#         [134, 180, 198],
#         ...,
#         [240, 248, 248],
#         [239, 244, 243],
#         [235, 240, 239]],
#
#        [[130, 176, 194],
#         [133, 179, 197],
#         [136, 182, 200],
# ...

# %%
plt.imshow(img)
