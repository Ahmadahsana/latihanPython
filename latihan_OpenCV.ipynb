# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
gambar = cv2.imread('gambar/3.jpg')

# %%
gambar
# Out:
# array([[[212, 162, 120],
#         [212, 162, 120],
#         [212, 162, 120],
#         ...,
#         [222, 188, 158],
#         [220, 186, 156],
#         [218, 184, 154]],
#
#        [[212, 162, 120],
#         [212, 162, 120],
#         [212, 162, 120],
#         ...,
#         [222, 188, 158],
#         [221, 187, 157],
#         [219, 185, 155]],
#
#        [[212, 162, 120],
#         [212, 162, 120],
#         [212, 162, 120],
#         ...,
#         [222, 188, 158],
#         [221, 187, 157],
#         [220, 186, 156]],
#
#        ...,
#
#        [[208, 165, 122],
#         [208, 165, 122],
#         [208, 165, 122],
#         ...,
#         [210, 173, 139],
#         [210, 173, 139],
#         [210, 173, 139]],
#
#        [[208, 165, 122],
#         [208, 165, 122],
#         [208, 165, 122],
#         ...,
#         [210, 173, 139],
#         [210, 173, 139],
#         [210, 173, 139]],
#
#        [[208, 165, 122],
#         [208, 165, 122],
#         [208, 165, 122],
# ...

# %%
gambar.shape
# Out:
# (591, 1080, 3)

# %%
plt.imshow(gambar)

# %%
#matplotlib ------> RGB (red,green,blue)
#openCV ----------> BGR (blue, green, red)

# %%
fix_gambar = cv2.cvtColor(gambar, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_gambar)

# %%
gambar_abu = cv2.imread('gambar/3.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(gambar_abu, cmap='gray')

# %%
plt.imshow(fix_gambar)

# %%
gambar_resize = cv2.resize(fix_gambar, (800,600))

# %%
plt.imshow(gambar_resize)
