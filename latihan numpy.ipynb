# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
pic = Image.open('gambar/1.jpg')

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (900, 1200, 3)

# %%
plt.imshow(pic)

# %%
plt.imshow(pic_arr)

# %%
pic_red = pic_arr.copy()

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (900, 1200, 3)

# %%
plt.imshow(pic_red[:,:,0], cmap='gray')

# %%
plt.imshow(pic_red[:,:,1], cmap='gray')

# %%
pic_red[:,:,1]
# Out:
# array([[221, 221, 221, ...,  59,  61,  63],
#        [224, 223, 223, ...,  60,  62,  63],
#        [229, 228, 228, ...,  61,  63,  64],
#        ...,
#        [142, 140, 154, ..., 154, 147, 141],
#        [138, 147, 172, ..., 135, 131, 128],
#        [138, 153, 185, ..., 125, 124, 126]], dtype=uint8)

# %%
pic_red[:,:,2] = 0

# %%
plt.imshow(pic_red)

# %%
pic_red[:,:,0]
# Out:
# array([[208, 208, 208, ...,  72,  74,  76],
#        [211, 210, 210, ...,  73,  75,  76],
#        [213, 212, 212, ...,  74,  76,  77],
#        ...,
#        [149, 147, 161, ..., 166, 159, 153],
#        [145, 154, 179, ..., 147, 143, 140],
#        [145, 160, 192, ..., 137, 136, 138]], dtype=uint8)

# %%
plt.imshow(pic_red)

# %%
pic_red.shape
# Out:
# (900, 1200, 3)

# %%
pic_red[:,:,0].shape
# Out:
# (900, 1200)
