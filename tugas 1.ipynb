# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
mat = np.zeros(shape=(5,5))

# %%
mat[:,:] = 10

# %%
mat
# Out:
# array([[10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.],
#        [10., 10., 10., 10., 10.]])

# %%
#baris ini set matrix acak 
random1 = np.random.seed(101)

# %%
random1

# %%
arr = np.random.randint(low=0, high=100, size=(5,5))

# %%
arr
# Out:
# array([[95, 11, 81, 70, 63],
#        [87, 75,  9, 77, 40],
#        [ 4, 63, 40, 60, 92],
#        [64,  5, 12, 93, 40],
#        [49, 83,  8, 29, 59]])

# %%
arr
# Out:
# array([[95, 11, 81, 70, 63],
#        [87, 75,  9, 77, 40],
#        [ 4, 63, 40, 60, 92],
#        [64,  5, 12, 93, 40],
#        [49, 83,  8, 29, 59]])

# %%
arr[2,0]
# Out:
# 4

# %%
arr[0,0]
# Out:
# 95

# %%
pic = Image.open('gambar/3.jpg')

# %%
plt.imshow(pic)

# %%
pic_arr = np.asarray(pic)

# %%
pic_arr.shape
# Out:
# (591, 1080, 3)

# %%
cupang_merah = pic_arr.copy()

# %%
plt.imshow(cupang_merah)

# %%
plt.imshow(cupang_merah[:,:,0], cmap='gray')

# %%
cupang_merah[:,:,1]
# Out:
# array([[162, 162, 162, ..., 188, 186, 184],
#        [162, 162, 162, ..., 188, 187, 185],
#        [162, 162, 162, ..., 188, 187, 186],
#        ...,
#        [165, 165, 165, ..., 173, 173, 173],
#        [165, 165, 165, ..., 173, 173, 173],
#        [165, 165, 165, ..., 173, 173, 173]], dtype=uint8)

# %%
plt.imshow(cupang_merah[:,:,2])

# %%
plt.imshow(cupang_merah)

# %%
cupang_biru = pic_arr.copy()

# %%
plt.imshow(cupang_biru)

# %%
#shape [panjang,lebar,RGB]

# R G B

#red to zero
cupang_biru[:,:,0] = 0

#green to zero
cupang_biru[:,:,1] = 0

# %%
plt.imshow(cupang_biru)
